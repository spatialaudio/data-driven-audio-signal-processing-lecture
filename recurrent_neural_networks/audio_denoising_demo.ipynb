# %% [markdown]
# ## Demonstration of Audio Denoising
#
# This jupyter notebook is part of a [collection of notebooks](../index.ipynb) on various topics of Data-Driven Signal Processing. Please direct questions and suggestions to [Sascha.Spors@uni-rostock.de](mailto:Sascha.Spors@uni-rostock.de).

# %% [markdown]
# The denoising of audio samples is demonstrated using a deep recurrent neural network (RNN) constructed from layers of long short-term memory (LSTM) cells. The noisy input signal is split into overlapping segments and the magnitude of the short-time Fourier transform (STFT) of the current and 7 past segments is used as feature. The output for the supervised training is the magnitude of the STFT of the current segment of the noise-free signal.

# %%
import numpy as np
import matplotlib.pyplot as plt
import soundfile as sf

from scipy.signal import decimate
from librosa import stft, istft

from sklearn.model_selection import train_test_split

from tensorflow.keras.layers import Input, Dense, Activation, Flatten, Normalization, LSTM
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping

# %%
training_path = '../data/froschkoenig_female_speaker.wav'  # clean audio file used for training
noise_path = '../data/babble_noise.wav'  # additive noise for impairment of clean audio
testing_path = '../data/single_words_female_speaker.wav'  # clean audio used for testing the network

# %% [markdown]
# ### Generate Examples
#
# The features/outputs used for training the regression network are computed by impairing a clean speech recording by babble noise.

# %%
def generate_features(y, n, n_fft=256, hop_length=64, nseg=8):

    # normalize inputs
    y = y/np.max(np.abs(y[:]))
    n = n/np.max(np.abs(n[:]))

    # add background noise to signal
    x = y + .7 * n[:len(y)]
    x = x/np.max(np.abs(x[:]))

    # STFTs of clean and noisy signal
    Y = stft(y, n_fft=n_fft, hop_length=hop_length).T
    Y = np.abs(Y)
    X = stft(x, n_fft=n_fft, hop_length=hop_length).T
    phiX = np.angle(X[nseg-1:, :])
    X = np.abs(X)

    # stack segments as features
    Y = Y[nseg-1:, :]
    X = [X[n:n+nseg, :] for n in range(len(Y))]
    X = np.array(X)

    return X, x, Y, phiX

# %%
y, fs = sf.read(training_path)
y = decimate(y, 2)
fs = fs//2

n, _ = sf.read(noise_path)
n = n[:, 0]
n = decimate(n, 2)
n = np.hstack((n, n, n))

X, x, Y, phiX = generate_features(y, n)

print(f'dimensions of features {X.shape}')
print(f'dimensions of outputs {Y.shape}')
# Out:
# dimensions of features (49956, 8, 129)
# dimensions of outputs (49956, 129)

# %% [markdown]
# Let's listen to the noisy audio used for the training

# %%
sf.write('training_example.wav', x, fs)

# %% [markdown]
# <audio src="training_example.wav" controls>

# %% [markdown]
# ### Define and Train the Model
#
# The model is defined as a concatenation of an input layer, a normalization layer and four LSTM layers. For the model, the output shapes of the individual layers, as well as the number of parameters that have to be determined in the training phase are summarized below.

# %%
normalizer = Normalization()


def dnn_model(input_shape=(8, 129)):

    inputs = Input(shape=input_shape)

    x = normalizer(inputs)

    x = LSTM(129, activation='relu', return_sequences=True)(x)
    x = LSTM(129, activation='relu', return_sequences=True)(x)
    x = LSTM(129, activation='relu', return_sequences=True)(x)
    x = LSTM(129, activation='relu')(x)

    return Model(inputs, x)


model = dnn_model()
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 8, 129)]          0
#
#  normalization (Normalizatio  (None, 8, 129)           259
#  n)
#
#  lstm (LSTM)                 (None, 8, 129)            133644
#
#  lstm_1 (LSTM)               (None, 8, 129)            133644
#
#  lstm_2 (LSTM)               (None, 8, 129)            133644
#
#  lstm_3 (LSTM)               (None, 129)               133644
#
# =================================================================
# Total params: 534,835
# Trainable params: 534,576
# Non-trainable params: 259
# _________________________________________________________________
# 2022-02-08 17:44:32.943384: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# Now the model is 'compiled' using the mean-squared error (MSE) as loss function together with the Adam optimizer. The examples are split into two subsets of training and validation examples. In order to avoid overfitting, Early Stopping is used to stop the training after convergence has been reached.

# %%
model.compile(loss="mse", optimizer="adam")

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)

normalizer.adapt(X_train)

stop_early = EarlyStopping(monitor='val_loss', patience=5)
history = model.fit(X, Y, validation_data=(X_test, Y_test),
                    callbacks=[stop_early], epochs=100, batch_size=64)
# Out:
# Epoch 1/100
# 781/781 [==============================] - 31s 36ms/step - loss: 0.2650 - val_loss: 0.1325
# Epoch 2/100
# 781/781 [==============================] - 26s 34ms/step - loss: 0.1156 - val_loss: 0.1039
# Epoch 3/100
# 781/781 [==============================] - 26s 33ms/step - loss: 0.0942 - val_loss: 0.0824
# Epoch 4/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.0819 - val_loss: 0.0758
# Epoch 5/100
# 781/781 [==============================] - 27s 34ms/step - loss: 0.0738 - val_loss: 0.0674
# Epoch 6/100
# 781/781 [==============================] - 31s 39ms/step - loss: 0.0658 - val_loss: 0.0588
# Epoch 7/100
# 781/781 [==============================] - 26s 34ms/step - loss: 0.0617 - val_loss: 0.0622
# Epoch 8/100
# 781/781 [==============================] - 25s 33ms/step - loss: 0.0570 - val_loss: 0.0528
# Epoch 9/100
# 781/781 [==============================] - 26s 34ms/step - loss: 0.0528 - val_loss: 0.0480
# Epoch 10/100
# 781/781 [==============================] - 28s 36ms/step - loss: 0.0497 - val_loss: 0.0527
# Epoch 11/100
# 781/781 [==============================] - 28s 36ms/step - loss: 0.0476 - val_loss: 0.0424
# Epoch 12/100
# 781/781 [==============================] - 26s 33ms/step - loss: 0.0444 - val_loss: 0.0441
# Epoch 13/100
# 781/781 [==============================] - 26s 34ms/step - loss: 0.0420 - val_loss: 0.0391
# Epoch 14/100
# 781/781 [==============================] - 31s 39ms/step - loss: 0.0398 - val_loss: 0.0395
# Epoch 15/100
# 781/781 [==============================] - 29s 37ms/step - loss: 0.0382 - val_loss: 0.0351
# Epoch 16/100
# 781/781 [==============================] - 30s 39ms/step - loss: 0.0366 - val_loss: 0.0344
# Epoch 17/100
# 781/781 [==============================] - 28s 36ms/step - loss: 0.0351 - val_loss: 0.0323
# Epoch 18/100
# 781/781 [==============================] - 30s 39ms/step - loss: 0.0339 - val_loss: 0.0323
# Epoch 19/100
# 781/781 [==============================] - 27s 34ms/step - loss: 0.0324 - val_loss: 0.0326
# Epoch 20/100
# 781/781 [==============================] - 28s 36ms/step - loss: 0.0313 - val_loss: 0.0300
# Epoch 21/100
# 781/781 [==============================] - 28s 36ms/step - loss: 0.0303 - val_loss: 0.0294
# Epoch 22/100
# 781/781 [==============================] - 29s 38ms/step - loss: 0.0294 - val_loss: 0.0286
# Epoch 23/100
# 781/781 [==============================] - 31s 40ms/step - loss: 0.0283 - val_loss: 0.0276
# Epoch 24/100
# 781/781 [==============================] - 31s 40ms/step - loss: 0.0275 - val_loss: 0.0265
# Epoch 25/100
# 781/781 [==============================] - 30s 38ms/step - loss: 0.0272 - val_loss: 0.0276
# Epoch 26/100
# 781/781 [==============================] - 26s 33ms/step - loss: 0.0263 - val_loss: 0.0249
# Epoch 27/100
# 781/781 [==============================] - 27s 35ms/step - loss: 0.0255 - val_loss: 0.0241
# Epoch 28/100
# 781/781 [==============================] - 26s 33ms/step - loss: 0.0251 - val_loss: 0.0244
# Epoch 29/100
# 781/781 [==============================] - 25s 33ms/step - loss: 0.0243 - val_loss: 0.0232
# Epoch 30/100
# 781/781 [==============================] - 26s 33ms/step - loss: 0.0239 - val_loss: 0.0220
# Epoch 31/100
# 781/781 [==============================] - 26s 33ms/step - loss: 0.0233 - val_loss: 0.0231
# Epoch 32/100
# 781/781 [==============================] - 26s 33ms/step - loss: 0.0231 - val_loss: 0.0216
# Epoch 33/100
# 781/781 [==============================] - 26s 33ms/step - loss: 0.0226 - val_loss: 0.0222
# Epoch 34/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.0222 - val_loss: 0.0224
# Epoch 35/100
# 781/781 [==============================] - 26s 33ms/step - loss: 0.0226 - val_loss: 0.0224
# Epoch 36/100
# 781/781 [==============================] - 27s 34ms/step - loss: 0.0214 - val_loss: 0.0204
# Epoch 37/100
# 781/781 [==============================] - 26s 33ms/step - loss: 0.0213 - val_loss: 0.0198
# Epoch 38/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.0203 - val_loss: 0.0194
# Epoch 39/100
# 781/781 [==============================] - 25s 33ms/step - loss: 0.0202 - val_loss: 0.0195
# Epoch 40/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.0199 - val_loss: 0.0205
# Epoch 41/100
# 781/781 [==============================] - 26s 33ms/step - loss: 0.0198 - val_loss: 0.0187
# Epoch 42/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.0193 - val_loss: 0.0184
# Epoch 43/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.0193 - val_loss: 0.0183
# Epoch 44/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.0191 - val_loss: 0.0186
# Epoch 45/100
# 781/781 [==============================] - 28s 36ms/step - loss: 0.0187 - val_loss: 0.0176
# Epoch 46/100
# 781/781 [==============================] - 29s 37ms/step - loss: 0.0182 - val_loss: 0.0175
# Epoch 47/100
# 781/781 [==============================] - 29s 37ms/step - loss: 0.0184 - val_loss: 0.0178
# Epoch 48/100
# 781/781 [==============================] - 28s 36ms/step - loss: 0.0181 - val_loss: 0.0180
# Epoch 49/100
# 781/781 [==============================] - 29s 37ms/step - loss: 0.0178 - val_loss: 0.0169
# Epoch 50/100
# 781/781 [==============================] - 30s 38ms/step - loss: 0.0176 - val_loss: 0.0174
# Epoch 51/100
# 781/781 [==============================] - 28s 36ms/step - loss: 0.0174 - val_loss: 0.0171
# Epoch 52/100
# 781/781 [==============================] - 29s 37ms/step - loss: 0.0170 - val_loss: 0.0164
# Epoch 53/100
# 781/781 [==============================] - 29s 37ms/step - loss: 0.0170 - val_loss: 0.0179
# Epoch 54/100
# 781/781 [==============================] - 30s 38ms/step - loss: 0.0169 - val_loss: 0.0165
# Epoch 55/100
# 781/781 [==============================] - 29s 37ms/step - loss: 0.0167 - val_loss: 0.0160
# Epoch 56/100
# 781/781 [==============================] - 30s 38ms/step - loss: 0.0166 - val_loss: 0.0152
# Epoch 57/100
# 781/781 [==============================] - 28s 36ms/step - loss: 0.0162 - val_loss: 0.0164
# Epoch 58/100
# 781/781 [==============================] - 30s 39ms/step - loss: 0.0162 - val_loss: 0.0155
# Epoch 59/100
# 781/781 [==============================] - 29s 37ms/step - loss: 0.0159 - val_loss: 0.0159
# Epoch 60/100
# 781/781 [==============================] - 28s 36ms/step - loss: 0.0158 - val_loss: 0.0151
# Epoch 61/100
# 781/781 [==============================] - 28s 36ms/step - loss: 0.0157 - val_loss: 0.0157
# Epoch 62/100
# 781/781 [==============================] - 29s 37ms/step - loss: 0.0161 - val_loss: 0.0152
# Epoch 63/100
# 781/781 [==============================] - 30s 38ms/step - loss: 0.0153 - val_loss: 0.0146
# Epoch 64/100
# 781/781 [==============================] - 28s 36ms/step - loss: 0.0152 - val_loss: 0.0148
# Epoch 65/100
# 781/781 [==============================] - 28s 36ms/step - loss: 0.0155 - val_loss: 0.0160
# Epoch 66/100
# 781/781 [==============================] - 28s 36ms/step - loss: 0.0151 - val_loss: 0.0154
# Epoch 67/100
# 781/781 [==============================] - 29s 37ms/step - loss: 0.0148 - val_loss: 0.0137
# Epoch 68/100
# 781/781 [==============================] - 30s 39ms/step - loss: 0.0147 - val_loss: 0.0148
# Epoch 69/100
# 781/781 [==============================] - 29s 37ms/step - loss: 0.0149 - val_loss: 0.0147
# Epoch 70/100
# 781/781 [==============================] - 29s 37ms/step - loss: 0.0147 - val_loss: 0.0136
# Epoch 71/100
# 781/781 [==============================] - 30s 39ms/step - loss: 0.0145 - val_loss: 0.0146
# Epoch 72/100
# 781/781 [==============================] - 30s 38ms/step - loss: 0.0144 - val_loss: 0.0145
# Epoch 73/100
# 781/781 [==============================] - 30s 39ms/step - loss: 0.0144 - val_loss: 0.0140
# Epoch 74/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.0141 - val_loss: 0.0138
# Epoch 75/100
# 781/781 [==============================] - 26s 33ms/step - loss: 0.0142 - val_loss: 0.0135
# Epoch 76/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.0140 - val_loss: 0.0143
# Epoch 77/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.0139 - val_loss: 0.0137
# Epoch 78/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.0138 - val_loss: 0.0132
# Epoch 79/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.0138 - val_loss: 0.0135
# Epoch 80/100
# 781/781 [==============================] - 25s 33ms/step - loss: 0.0135 - val_loss: 0.0129
# Epoch 81/100
# 781/781 [==============================] - 27s 35ms/step - loss: 0.0135 - val_loss: 0.0146
# Epoch 82/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.0137 - val_loss: 0.0128
# Epoch 83/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.0133 - val_loss: 0.0131
# Epoch 84/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.0134 - val_loss: 0.0132
# Epoch 85/100
# 781/781 [==============================] - 26s 34ms/step - loss: 0.0132 - val_loss: 0.0131
# Epoch 86/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.0132 - val_loss: 0.0135
# Epoch 87/100
# 781/781 [==============================] - 25s 32ms/step - loss: 0.0131 - val_loss: 0.0135

# %% [markdown]
# ### Evaluation of the Model
#
# First we take a look at the evolution of the mean-squared error over the epochs.

# %%
def plot_history(history, key):
    plt.figure()
    plt.plot(history.history[key], label='training')
    plt.plot(history.history[f'val_{key}'], label='validation')
    plt.title(f'model {key}')
    plt.ylabel(key)
    plt.xlabel('epoch')
    plt.legend()
    plt.grid()


plot_history(history, 'loss')

# %% [markdown]
# In order to test the model, an unseen audio example is denoised by the trained model. In order to denoise the signal with the trained network, the phase is extracted from the STFT before taking its magnitude. The input features are then fed through the network in order to compute the denoised STFT of the actual segment. The extracted phase is then used to recover the output segment using an inverse STFT.

# %%
y_test, _ = sf.read(testing_path)
y_test = decimate(y_test, 2)

X_test, x_test, Y_test, phiX_test = generate_features(y_test, n)

Yd = model.predict(X_test)
yd = istft(Yd.T * np.exp(1j*phiX_test).T)
yd = yd / np.max(np.abs(yd[:]))

sf.write('clean_example.wav', y_test, fs)
sf.write('noisy_example.wav', x_test, fs)
sf.write('denoised_example.wav', yd, fs)

# %% [markdown]
# Lets listen to the noisy and denoised example to explore the performance of the model

# %% [markdown]
# **Clean example**
#
# <audio src="clean_example.wav" controls>

# %% [markdown]
# **Example impaired by babble noise**
#
# <audio src="noisy_example.wav" controls>

# %% [markdown]
# **Denoised example**
#
# <audio src="denoised_example.wav" controls>

# %% [markdown]
# **Copyright**
#
# This notebook is provided as [Open Educational Resource](https://de.wikipedia.org/wiki/Open_Educational_Resources).
# The text is licensed under [Creative Commons Attribution 4.0](https://creativecommons.org/licenses/by/4.0/)
# , the code of the IPython examples under the [MIT license](https://opensource.org/licenses/MIT). Please attribute the work as follows: Sascha Spors, Data driven audio signal processing - Lecture supplementals.
