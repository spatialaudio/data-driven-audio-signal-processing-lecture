# %% [markdown]
# ## Demonstration of Spoken Digits Classification
#
# This jupyter notebook is part of a [collection of notebooks](../index.ipynb) on various topics of Data-Driven Signal Processing. Please direct questions and suggestions to [Sascha.Spors@uni-rostock.de](mailto:Sascha.Spors@uni-rostock.de).

# %% [markdown]
# This notebook demonstrates the classification of recorded spoken digits in the [Free Spoken Digit Dataset](https://github.com/Jakobovski/free-spoken-digit-dataset) (FSDD). Please download/clone the dataset before executing this notebook. Mel-Frequency Cepstral Coefficients (MFCCs) are used as two-dimensional features which are fed into a convolutive neural network (CNN) for classification.

# %%
import os
import glob

import numpy as np
import matplotlib.pyplot as plt
import soundfile as sf

from librosa.feature import mfcc

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Input, Dense, Dropout, Conv2D, Activation, Flatten, MaxPooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping

# %%
path = '../data/free-spoken-digit-dataset/recordings/'  # path to dataset

# %% [markdown]
# ### Load Dataset
#
# The FSDD consists of a series of wav files containing recordings of the single spoken digits `0-9` for different individuals. Each digit has been recorded multiple times for each individual. In the following, all samples in the database are loaded, normalized and truncated to a common length.

# %%
def load_examples(path):

    X = list()
    Y = list()

    audiofiles = glob.glob(path, recursive=True)
    for filepath in audiofiles:
        x, fs = sf.read(filepath)
        x = x / np.max(np.abs(x))
        X.append(x)
        Y.append(int(os.path.basename(filepath)[0]))

    return X, Y, fs


# load examples
X_raw, Y, fs = load_examples(path + '*.wav')

# determine maximum length of the examples
lengths = [len(x) for x in X_raw]
F = np.max(lengths)

# append zeros to examples to equalize lengths
X_raw = [np.concatenate((sample, np.zeros(F - len(sample))))
         for sample in X_raw]
X_raw = np.array(X_raw)
Y = np.array(Y)

# one-hot encoding of class labels
Y1h = to_categorical(Y, 10)

# %%
print('Total number of examples: {}'.format(len(X_raw)))
print('Number of samples per example: {}'.format(F))
# Out:
# Total number of examples: 3000
# Number of samples per example: 18262

# %% [markdown]
# ### Feature Extraction
#
# Now the MFCCs for each example are computed.

# %%
X = [mfcc(y=sample, sr=fs, htk=True) for sample in X_raw]
X = np.array(X)

print('Total number of examples: {}'.format(X.shape[0]))
print('Dimension of feature vectors: {}'.format(X.shape[1:]))
# Out:
# Total number of examples: 3000
# Dimension of feature vectors: (20, 36)

# %% [markdown]
# ### Define and Train the Model
#
# The model is defined as a concatenation of an input layer, two-dimensional convolutional layers, activation layers, pooling layers and an output layer. For the model, the output shapes of the individual layers, as well as the number of parameters that have to be determined in the training phase are summarized.

# %%
def dnn_model(input_shape=(20,36,1), classes=10):

    inputs = Input(shape=input_shape)

    z = Conv2D(8, (3,3))(inputs)
    z = Activation('relu')(z)
    z = MaxPooling2D((2,2))(z)
    z = Conv2D(16, (3,3))(z)
    z = Activation('relu')(z)
    z = MaxPooling2D((2,2))(z)
    
    z = Flatten()(z)
    z = Dense(classes, activation='softmax')(z)

    return Model(inputs, z)


model = dnn_model()
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 20, 36, 1)]       0
#
#  conv2d (Conv2D)             (None, 18, 34, 8)         80
#
#  activation (Activation)     (None, 18, 34, 8)         0
#
#  max_pooling2d (MaxPooling2D  (None, 9, 17, 8)         0
#  )
#
#  conv2d_1 (Conv2D)           (None, 7, 15, 16)         1168
#
#  activation_1 (Activation)   (None, 7, 15, 16)         0
#
#  max_pooling2d_1 (MaxPooling  (None, 3, 7, 16)         0
#  2D)
#
#  flatten (Flatten)           (None, 336)               0
#
#  dense (Dense)               (None, 10)                3370
#
# =================================================================
# Total params: 4,618
# Trainable params: 4,618
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Now the model is compiled and trained. We used the `categorical crossentropy` as loss and the `Adam` optimizer. As evaluation metrics, the accuracy of the prediction is used. The examples are split into a set of examples used for training and a set used for validation of the trained model. The loss and the accuracy is plotted for each epoch for both the training and validation subsets. Early stopping is used to prevent overfitting of the model.

# %%
model.compile(loss="categorical_crossentropy",
              optimizer="adam", metrics=["accuracy"])

X_train, X_test, Y_train, Y_test = train_test_split(X, Y1h, test_size=0.2)

callback = EarlyStopping(monitor='accuracy', patience=15)
history = model.fit(X_train, Y_train, validation_data=(
    X_test, Y_test), callbacks=[callback], epochs=200, batch_size=128)
# Out:
# Epoch 1/200
# 19/19 [==============================] - 1s 23ms/step - loss: 28.0871 - accuracy: 0.1300 - val_loss: 9.8694 - val_accuracy: 0.1933
# Epoch 2/200
# 19/19 [==============================] - 0s 17ms/step - loss: 6.0116 - accuracy: 0.1442 - val_loss: 3.9918 - val_accuracy: 0.2433
# Epoch 3/200
# 19/19 [==============================] - 0s 17ms/step - loss: 3.3903 - accuracy: 0.2296 - val_loss: 2.6992 - val_accuracy: 0.2733
# Epoch 4/200
# 19/19 [==============================] - 0s 19ms/step - loss: 2.5204 - accuracy: 0.3029 - val_loss: 2.1870 - val_accuracy: 0.3417
# Epoch 5/200
# 19/19 [==============================] - 0s 13ms/step - loss: 2.0657 - accuracy: 0.3592 - val_loss: 1.8102 - val_accuracy: 0.4000
# Epoch 6/200
# 19/19 [==============================] - 0s 13ms/step - loss: 1.7394 - accuracy: 0.4283 - val_loss: 1.5382 - val_accuracy: 0.4717
# Epoch 7/200
# 19/19 [==============================] - 0s 12ms/step - loss: 1.4732 - accuracy: 0.4992 - val_loss: 1.3141 - val_accuracy: 0.5550
# Epoch 8/200
# 19/19 [==============================] - 0s 18ms/step - loss: 1.2785 - accuracy: 0.5537 - val_loss: 1.1657 - val_accuracy: 0.6117
# Epoch 9/200
# 19/19 [==============================] - 0s 15ms/step - loss: 1.1301 - accuracy: 0.6121 - val_loss: 1.0505 - val_accuracy: 0.6450
# Epoch 10/200
# 19/19 [==============================] - 0s 19ms/step - loss: 1.0078 - accuracy: 0.6558 - val_loss: 0.9046 - val_accuracy: 0.6817
# Epoch 11/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.8686 - accuracy: 0.7004 - val_loss: 0.8488 - val_accuracy: 0.7117
# Epoch 12/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.7915 - accuracy: 0.7304 - val_loss: 0.7589 - val_accuracy: 0.7617
# Epoch 13/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.7026 - accuracy: 0.7688 - val_loss: 0.6850 - val_accuracy: 0.7733
# Epoch 14/200
# 19/19 [==============================] - 0s 13ms/step - loss: 0.6269 - accuracy: 0.7933 - val_loss: 0.6255 - val_accuracy: 0.8033
# Epoch 15/200
# 19/19 [==============================] - 0s 20ms/step - loss: 0.5784 - accuracy: 0.8150 - val_loss: 0.5848 - val_accuracy: 0.8250
# Epoch 16/200
# 19/19 [==============================] - 0s 17ms/step - loss: 0.5232 - accuracy: 0.8388 - val_loss: 0.5637 - val_accuracy: 0.8267
# Epoch 17/200
# 19/19 [==============================] - 0s 21ms/step - loss: 0.4881 - accuracy: 0.8500 - val_loss: 0.5323 - val_accuracy: 0.8217
# Epoch 18/200
# 19/19 [==============================] - 0s 13ms/step - loss: 0.4531 - accuracy: 0.8546 - val_loss: 0.4789 - val_accuracy: 0.8633
# Epoch 19/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.4085 - accuracy: 0.8763 - val_loss: 0.4653 - val_accuracy: 0.8483
# Epoch 20/200
# 19/19 [==============================] - 0s 13ms/step - loss: 0.3842 - accuracy: 0.8846 - val_loss: 0.4399 - val_accuracy: 0.8717
# Epoch 21/200
# 19/19 [==============================] - 0s 17ms/step - loss: 0.3573 - accuracy: 0.8942 - val_loss: 0.4353 - val_accuracy: 0.8600
# Epoch 22/200
# 19/19 [==============================] - 0s 16ms/step - loss: 0.3342 - accuracy: 0.9038 - val_loss: 0.3945 - val_accuracy: 0.8733
# Epoch 23/200
# 19/19 [==============================] - 0s 17ms/step - loss: 0.3109 - accuracy: 0.9096 - val_loss: 0.4021 - val_accuracy: 0.8750
# Epoch 24/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.2995 - accuracy: 0.9125 - val_loss: 0.3826 - val_accuracy: 0.8767
# Epoch 25/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.2717 - accuracy: 0.9242 - val_loss: 0.3658 - val_accuracy: 0.8950
# Epoch 26/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.2610 - accuracy: 0.9279 - val_loss: 0.3415 - val_accuracy: 0.8900
# Epoch 27/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.2467 - accuracy: 0.9275 - val_loss: 0.3431 - val_accuracy: 0.8950
# Epoch 28/200
# 19/19 [==============================] - 0s 16ms/step - loss: 0.2331 - accuracy: 0.9325 - val_loss: 0.3341 - val_accuracy: 0.8867
# Epoch 29/200
# 19/19 [==============================] - 0s 16ms/step - loss: 0.2223 - accuracy: 0.9337 - val_loss: 0.3259 - val_accuracy: 0.9167
# Epoch 30/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.2109 - accuracy: 0.9392 - val_loss: 0.3187 - val_accuracy: 0.9117
# Epoch 31/200
# 19/19 [==============================] - 0s 22ms/step - loss: 0.1968 - accuracy: 0.9454 - val_loss: 0.2943 - val_accuracy: 0.9100
# Epoch 32/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1972 - accuracy: 0.9413 - val_loss: 0.3521 - val_accuracy: 0.8933
# Epoch 33/200
# 19/19 [==============================] - 0s 13ms/step - loss: 0.1871 - accuracy: 0.9463 - val_loss: 0.2978 - val_accuracy: 0.9183
# Epoch 34/200
# 19/19 [==============================] - 0s 13ms/step - loss: 0.1755 - accuracy: 0.9508 - val_loss: 0.2808 - val_accuracy: 0.9217
# Epoch 35/200
# 19/19 [==============================] - 0s 13ms/step - loss: 0.1627 - accuracy: 0.9529 - val_loss: 0.2730 - val_accuracy: 0.9267
# Epoch 36/200
# 19/19 [==============================] - 0s 19ms/step - loss: 0.1635 - accuracy: 0.9542 - val_loss: 0.2854 - val_accuracy: 0.9183
# Epoch 37/200
# 19/19 [==============================] - 0s 16ms/step - loss: 0.1561 - accuracy: 0.9558 - val_loss: 0.2761 - val_accuracy: 0.9217
# Epoch 38/200
# 19/19 [==============================] - 0s 21ms/step - loss: 0.1458 - accuracy: 0.9600 - val_loss: 0.2721 - val_accuracy: 0.9233
# Epoch 39/200
# 19/19 [==============================] - 0s 23ms/step - loss: 0.1386 - accuracy: 0.9646 - val_loss: 0.2893 - val_accuracy: 0.9117
# Epoch 40/200
# 19/19 [==============================] - 0s 16ms/step - loss: 0.1344 - accuracy: 0.9650 - val_loss: 0.2670 - val_accuracy: 0.9167
# Epoch 41/200
# 19/19 [==============================] - 0s 21ms/step - loss: 0.1346 - accuracy: 0.9642 - val_loss: 0.2567 - val_accuracy: 0.9217
# Epoch 42/200
# 19/19 [==============================] - 0s 21ms/step - loss: 0.1260 - accuracy: 0.9629 - val_loss: 0.2580 - val_accuracy: 0.9250
# Epoch 43/200
# 19/19 [==============================] - 0s 20ms/step - loss: 0.1205 - accuracy: 0.9692 - val_loss: 0.2601 - val_accuracy: 0.9200
# Epoch 44/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1253 - accuracy: 0.9642 - val_loss: 0.2414 - val_accuracy: 0.9250
# Epoch 45/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1173 - accuracy: 0.9688 - val_loss: 0.2471 - val_accuracy: 0.9233
# Epoch 46/200
# 19/19 [==============================] - 0s 16ms/step - loss: 0.1114 - accuracy: 0.9658 - val_loss: 0.2616 - val_accuracy: 0.9233
# Epoch 47/200
# 19/19 [==============================] - 0s 18ms/step - loss: 0.1041 - accuracy: 0.9729 - val_loss: 0.2427 - val_accuracy: 0.9283
# Epoch 48/200
# 19/19 [==============================] - 0s 20ms/step - loss: 0.1001 - accuracy: 0.9754 - val_loss: 0.2343 - val_accuracy: 0.9367
# Epoch 49/200
# 19/19 [==============================] - 0s 17ms/step - loss: 0.0955 - accuracy: 0.9742 - val_loss: 0.2668 - val_accuracy: 0.9233
# Epoch 50/200
# 19/19 [==============================] - 0s 13ms/step - loss: 0.0934 - accuracy: 0.9733 - val_loss: 0.2363 - val_accuracy: 0.9317
# Epoch 51/200
# 19/19 [==============================] - 0s 22ms/step - loss: 0.0846 - accuracy: 0.9783 - val_loss: 0.2340 - val_accuracy: 0.9300
# Epoch 52/200
# 19/19 [==============================] - 1s 29ms/step - loss: 0.0852 - accuracy: 0.9762 - val_loss: 0.2438 - val_accuracy: 0.9283
# Epoch 53/200
# 19/19 [==============================] - 0s 17ms/step - loss: 0.0818 - accuracy: 0.9796 - val_loss: 0.2384 - val_accuracy: 0.9283
# Epoch 54/200
# 19/19 [==============================] - 0s 25ms/step - loss: 0.0790 - accuracy: 0.9796 - val_loss: 0.2449 - val_accuracy: 0.9333
# Epoch 55/200
# 19/19 [==============================] - 0s 17ms/step - loss: 0.0736 - accuracy: 0.9817 - val_loss: 0.2366 - val_accuracy: 0.9333
# Epoch 56/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0721 - accuracy: 0.9817 - val_loss: 0.2304 - val_accuracy: 0.9333
# Epoch 57/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0684 - accuracy: 0.9842 - val_loss: 0.2203 - val_accuracy: 0.9383
# Epoch 58/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0715 - accuracy: 0.9808 - val_loss: 0.2252 - val_accuracy: 0.9400
# Epoch 59/200
# 19/19 [==============================] - 0s 13ms/step - loss: 0.0725 - accuracy: 0.9796 - val_loss: 0.2414 - val_accuracy: 0.9300
# Epoch 60/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0634 - accuracy: 0.9854 - val_loss: 0.2327 - val_accuracy: 0.9350
# Epoch 61/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0593 - accuracy: 0.9846 - val_loss: 0.2152 - val_accuracy: 0.9467
# Epoch 62/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0573 - accuracy: 0.9862 - val_loss: 0.2196 - val_accuracy: 0.9383
# Epoch 63/200
# 19/19 [==============================] - 0s 13ms/step - loss: 0.0576 - accuracy: 0.9858 - val_loss: 0.2368 - val_accuracy: 0.9333
# Epoch 64/200
# 19/19 [==============================] - 0s 13ms/step - loss: 0.0518 - accuracy: 0.9896 - val_loss: 0.2192 - val_accuracy: 0.9383
# Epoch 65/200
# 19/19 [==============================] - 0s 16ms/step - loss: 0.0509 - accuracy: 0.9875 - val_loss: 0.2231 - val_accuracy: 0.9417
# Epoch 66/200
# 19/19 [==============================] - 0s 16ms/step - loss: 0.0481 - accuracy: 0.9908 - val_loss: 0.2189 - val_accuracy: 0.9417
# Epoch 67/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0492 - accuracy: 0.9883 - val_loss: 0.2379 - val_accuracy: 0.9333
# Epoch 68/200
# 19/19 [==============================] - 0s 13ms/step - loss: 0.0483 - accuracy: 0.9892 - val_loss: 0.2184 - val_accuracy: 0.9383
# Epoch 69/200
# 19/19 [==============================] - 0s 13ms/step - loss: 0.0449 - accuracy: 0.9892 - val_loss: 0.2166 - val_accuracy: 0.9483
# Epoch 70/200
# 19/19 [==============================] - 0s 13ms/step - loss: 0.0439 - accuracy: 0.9900 - val_loss: 0.2108 - val_accuracy: 0.9450
# Epoch 71/200
# 19/19 [==============================] - 0s 12ms/step - loss: 0.0429 - accuracy: 0.9912 - val_loss: 0.2179 - val_accuracy: 0.9483
# Epoch 72/200
# 19/19 [==============================] - 0s 13ms/step - loss: 0.0390 - accuracy: 0.9933 - val_loss: 0.2083 - val_accuracy: 0.9450
# Epoch 73/200
# 19/19 [==============================] - 0s 13ms/step - loss: 0.0374 - accuracy: 0.9942 - val_loss: 0.2203 - val_accuracy: 0.9433
# Epoch 74/200
# 19/19 [==============================] - 0s 13ms/step - loss: 0.0375 - accuracy: 0.9925 - val_loss: 0.2004 - val_accuracy: 0.9483
# Epoch 75/200
# 19/19 [==============================] - 0s 16ms/step - loss: 0.0343 - accuracy: 0.9946 - val_loss: 0.2147 - val_accuracy: 0.9417
# Epoch 76/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0357 - accuracy: 0.9921 - val_loss: 0.2076 - val_accuracy: 0.9467
# Epoch 77/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0374 - accuracy: 0.9925 - val_loss: 0.2078 - val_accuracy: 0.9483
# Epoch 78/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0364 - accuracy: 0.9917 - val_loss: 0.2183 - val_accuracy: 0.9383
# Epoch 79/200
# 19/19 [==============================] - 0s 13ms/step - loss: 0.0334 - accuracy: 0.9933 - val_loss: 0.2129 - val_accuracy: 0.9467
# Epoch 80/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0295 - accuracy: 0.9954 - val_loss: 0.2052 - val_accuracy: 0.9517
# Epoch 81/200
# 19/19 [==============================] - 0s 17ms/step - loss: 0.0292 - accuracy: 0.9958 - val_loss: 0.2099 - val_accuracy: 0.9433
# Epoch 82/200
# 19/19 [==============================] - 0s 16ms/step - loss: 0.0301 - accuracy: 0.9950 - val_loss: 0.2175 - val_accuracy: 0.9467
# Epoch 83/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0296 - accuracy: 0.9962 - val_loss: 0.2110 - val_accuracy: 0.9500
# Epoch 84/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0273 - accuracy: 0.9967 - val_loss: 0.2036 - val_accuracy: 0.9450
# Epoch 85/200
# 19/19 [==============================] - 0s 13ms/step - loss: 0.0279 - accuracy: 0.9958 - val_loss: 0.2000 - val_accuracy: 0.9533
# Epoch 86/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0251 - accuracy: 0.9975 - val_loss: 0.2114 - val_accuracy: 0.9500
# Epoch 87/200
# 19/19 [==============================] - 0s 13ms/step - loss: 0.0243 - accuracy: 0.9962 - val_loss: 0.2036 - val_accuracy: 0.9517
# Epoch 88/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0226 - accuracy: 0.9967 - val_loss: 0.2050 - val_accuracy: 0.9517
# Epoch 89/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0215 - accuracy: 0.9983 - val_loss: 0.2091 - val_accuracy: 0.9500
# Epoch 90/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0223 - accuracy: 0.9983 - val_loss: 0.2039 - val_accuracy: 0.9483
# Epoch 91/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0210 - accuracy: 0.9975 - val_loss: 0.2122 - val_accuracy: 0.9483
# Epoch 92/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0226 - accuracy: 0.9958 - val_loss: 0.2047 - val_accuracy: 0.9483
# Epoch 93/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0212 - accuracy: 0.9979 - val_loss: 0.2003 - val_accuracy: 0.9517
# Epoch 94/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0205 - accuracy: 0.9975 - val_loss: 0.1980 - val_accuracy: 0.9567
# Epoch 95/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0197 - accuracy: 0.9975 - val_loss: 0.1943 - val_accuracy: 0.9567
# Epoch 96/200
# 19/19 [==============================] - 0s 13ms/step - loss: 0.0188 - accuracy: 0.9979 - val_loss: 0.1973 - val_accuracy: 0.9517
# Epoch 97/200
# 19/19 [==============================] - 0s 13ms/step - loss: 0.0179 - accuracy: 0.9992 - val_loss: 0.2012 - val_accuracy: 0.9483
# Epoch 98/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0175 - accuracy: 0.9987 - val_loss: 0.1938 - val_accuracy: 0.9517
# Epoch 99/200
# 19/19 [==============================] - 0s 13ms/step - loss: 0.0173 - accuracy: 0.9983 - val_loss: 0.2043 - val_accuracy: 0.9517
# Epoch 100/200
# 19/19 [==============================] - 0s 13ms/step - loss: 0.0169 - accuracy: 0.9983 - val_loss: 0.2133 - val_accuracy: 0.9500
# Epoch 101/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0167 - accuracy: 0.9987 - val_loss: 0.2065 - val_accuracy: 0.9583
# Epoch 102/200
# 19/19 [==============================] - 0s 13ms/step - loss: 0.0159 - accuracy: 0.9987 - val_loss: 0.1985 - val_accuracy: 0.9517
# Epoch 103/200
# 19/19 [==============================] - 0s 13ms/step - loss: 0.0154 - accuracy: 0.9987 - val_loss: 0.1987 - val_accuracy: 0.9533
# Epoch 104/200
# 19/19 [==============================] - 0s 13ms/step - loss: 0.0151 - accuracy: 0.9987 - val_loss: 0.2043 - val_accuracy: 0.9533
# Epoch 105/200
# 19/19 [==============================] - 0s 13ms/step - loss: 0.0140 - accuracy: 0.9992 - val_loss: 0.2056 - val_accuracy: 0.9517
# Epoch 106/200
# 19/19 [==============================] - 0s 13ms/step - loss: 0.0136 - accuracy: 0.9996 - val_loss: 0.2043 - val_accuracy: 0.9550
# Epoch 107/200
# 19/19 [==============================] - 0s 13ms/step - loss: 0.0138 - accuracy: 0.9987 - val_loss: 0.1957 - val_accuracy: 0.9567
# Epoch 108/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0149 - accuracy: 0.9979 - val_loss: 0.2002 - val_accuracy: 0.9483
# Epoch 109/200
# 19/19 [==============================] - 0s 13ms/step - loss: 0.0132 - accuracy: 0.9987 - val_loss: 0.1889 - val_accuracy: 0.9583
# Epoch 110/200
# 19/19 [==============================] - 0s 13ms/step - loss: 0.0134 - accuracy: 0.9987 - val_loss: 0.1962 - val_accuracy: 0.9567
# Epoch 111/200
# 19/19 [==============================] - 0s 13ms/step - loss: 0.0120 - accuracy: 0.9992 - val_loss: 0.2033 - val_accuracy: 0.9550
# Epoch 112/200
# 19/19 [==============================] - 0s 13ms/step - loss: 0.0120 - accuracy: 0.9992 - val_loss: 0.1901 - val_accuracy: 0.9600
# Epoch 113/200
# 19/19 [==============================] - 0s 13ms/step - loss: 0.0117 - accuracy: 0.9996 - val_loss: 0.2067 - val_accuracy: 0.9633
# Epoch 114/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0130 - accuracy: 0.9987 - val_loss: 0.2164 - val_accuracy: 0.9550
# Epoch 115/200
# 19/19 [==============================] - 0s 13ms/step - loss: 0.0124 - accuracy: 0.9996 - val_loss: 0.2136 - val_accuracy: 0.9567
# Epoch 116/200
# 19/19 [==============================] - 0s 12ms/step - loss: 0.0118 - accuracy: 0.9992 - val_loss: 0.2053 - val_accuracy: 0.9550
# Epoch 117/200
# 19/19 [==============================] - 0s 13ms/step - loss: 0.0120 - accuracy: 0.9996 - val_loss: 0.1991 - val_accuracy: 0.9567
# Epoch 118/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.0105 - accuracy: 0.9987 - val_loss: 0.1998 - val_accuracy: 0.9617
# Epoch 119/200
# 19/19 [==============================] - 0s 16ms/step - loss: 0.0098 - accuracy: 0.9992 - val_loss: 0.1955 - val_accuracy: 0.9583
# Epoch 120/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0096 - accuracy: 0.9996 - val_loss: 0.1964 - val_accuracy: 0.9583
# Epoch 121/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0093 - accuracy: 0.9992 - val_loss: 0.1979 - val_accuracy: 0.9567

# %% [markdown]
# ### Evaluation of the Model
#
# First we take a look at the evolution of the loss and the accuracy over the epochs

# %%
def plot_history(history, key):
    plt.figure()
    plt.plot(history.history[key], label='training')
    plt.plot(history.history[f'val_{key}'], label='validation')
    plt.title(f'model {key}')
    plt.ylabel(key)
    plt.xlabel('epoch')
    plt.legend()
    plt.grid()


plot_history(history, 'loss')
plot_history(history, 'accuracy')

# %% [markdown]
# The performance of the trained classifier on the validation examples is summarized in the classification report including various performance metrics

# %%
Y_pred = model.predict(X_test)
print(classification_report(np.argmax(Y_test, axis=1), np.argmax(Y_pred, axis=1)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99        67
#            1       0.96      1.00      0.98        53
#            2       0.95      0.95      0.95        66
#            3       0.94      0.93      0.94        55
#            4       1.00      0.99      0.99        68
#            5       0.95      0.98      0.97        63
#            6       0.90      0.98      0.94        54
#            7       0.94      0.86      0.90        59
#            8       0.98      0.94      0.96        67
#            9       0.92      0.92      0.92        48
#
#     accuracy                           0.96       600
#    macro avg       0.95      0.96      0.95       600
# weighted avg       0.96      0.96      0.96       600

# %% [markdown]
# **Copyright**
#
# This notebook is provided as [Open Educational Resource](https://de.wikipedia.org/wiki/Open_Educational_Resources).
# The text is licensed under [Creative Commons Attribution 4.0](https://creativecommons.org/licenses/by/4.0/)
# , the code of the IPython examples under the [MIT license](https://opensource.org/licenses/MIT). Please attribute the work as follows: Sascha Spors, Data driven audio signal processing - Lecture supplementals.
