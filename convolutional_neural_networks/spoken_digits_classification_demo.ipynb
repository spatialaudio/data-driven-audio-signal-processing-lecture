# %% [markdown]
# ## Demonstration of Spoken Digits Classification
#
# This jupyter notebook is part of a [collection of notebooks](../index.ipynb) on various topics of Data-Driven Signal Processing. Please direct questions and suggestions to [Sascha.Spors@uni-rostock.de](mailto:Sascha.Spors@uni-rostock.de).

# %% [markdown]
# This notebook demonstrates the classification of recorded spoken digits using the [AudioMNIST](https://github.com/soerenab/AudioMNIST) dataset. Please download/clone the dataset into the `data/` directory before executing this notebook. Mel-Frequency Cepstral Coefficients (MFCCs) are used as two-dimensional features fed into a convolutive neural network (CNN) for classification.

# %%
import os
import glob

import numpy as np
import matplotlib.pyplot as plt
import soundfile as sf

from librosa.feature import mfcc

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Input, Dense, Dropout, Conv2D, Activation, Flatten, MaxPooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping

# %%
path = '../data/AudioMNIST/data/**/'  # path to dataset

# %% [markdown]
# ### Load Dataset
#
# The AudioMNIST consists of a series of wav files containing recordings of the single spoken digits `0-9` for different individuals. Each digit has been recorded multiple times for each individual. In the following, all samples in the database are loaded, normalized and truncated to a common length.

# %%
def load_examples(path):

    X = list()
    Y = list()

    audiofiles = glob.glob(path, recursive=True)
    for filepath in audiofiles:
        x, fs = sf.read(filepath)
        x = x / np.max(np.abs(x))
        X.append(x)
        Y.append(int(os.path.basename(filepath)[0]))

    return X, Y, fs


# load examples
X_raw, Y, fs = load_examples(path + '*.wav')

# determine maximum length of the examples
lengths = [len(x) for x in X_raw]
F = np.max(lengths)

# append zeros to examples to equalize lengths
X_raw = [np.concatenate((sample, np.zeros(F - len(sample))))
         for sample in X_raw]
X_raw = np.array(X_raw)
Y = np.array(Y)

# one-hot encoding of class labels
Y1h = to_categorical(Y, 10)

# %%
print('Total number of examples: {}'.format(len(X_raw)))
print('Number of samples per example: {}'.format(F))
# Out:
# Total number of examples: 30000
# Number of samples per example: 47998

# %% [markdown]
# ### Feature Extraction
#
# Now the MFCCs for each example are computed.

# %%
X = [mfcc(y=sample, sr=fs, htk=True) for sample in X_raw]
X = np.array(X)

print('Total number of examples: {}'.format(X.shape[0]))
print('Dimension of feature vectors: {}'.format(X.shape[1:]))
# Out:
# Total number of examples: 30000
# Dimension of feature vectors: (20, 94)

# %% [markdown]
# ### Define and Train the Model
#
# The model is defined as a concatenation of an input layer, two-dimensional convolutional layers, activation layers, pooling layers and an output layer. For the model, the output shapes of the individual layers, as well as the number of parameters that have to be determined in the training phase are summarized.

# %%
def dnn_model(input_shape=(20,94,1), classes=10):

    inputs = Input(shape=input_shape)

    z = Conv2D(2, (3,3))(inputs)
    z = Activation('relu')(z)
    z = MaxPooling2D((2,2))(z)
    z = Conv2D(4, (3,3))(z)
    z = Activation('relu')(z)
    z = MaxPooling2D((2,2))(z)
    z = Conv2D(8, (3,3))(z)
    z = Activation('relu')(z)
    
    z = Flatten()(z)
    z = Dense(classes, activation='softmax')(z)

    return Model(inputs, z)


model = dnn_model()
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 20, 94, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 18, 92, 2)      │            20 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 18, 92, 2)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 9, 46, 2)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 7, 44, 4)       │            76 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 7, 44, 4)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 3, 22, 4)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 1, 20, 8)       │           296 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 1, 20, 8)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 160)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 10)             │         1,610 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,002 (7.82 KB)
#  Trainable params: 2,002 (7.82 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Now the model is compiled and trained. We used the `categorical crossentropy` as loss and the `Adam` optimizer. As evaluation metrics, the accuracy of the prediction is used. The examples are split into a set of examples used for training and a set used for validation of the trained model. The loss and the accuracy is plotted for each epoch for both the training and validation subsets. Early stopping is used to prevent overfitting of the model.

# %%
model.compile(loss="categorical_crossentropy",
              optimizer="adam", metrics=["accuracy"])

X_train, X_test, Y_train, Y_test = train_test_split(X, Y1h, test_size=0.2)

callback = EarlyStopping(monitor='val_accuracy')
history = model.fit(X_train, Y_train, validation_data=(
    X_test, Y_test), callbacks=[callback], epochs=200, batch_size=128)
# Out:
# Epoch 1/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.1925 - loss: 7.4022 - val_accuracy: 0.5465 - val_loss: 1.4087
# Epoch 2/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6195 - loss: 1.1659 - val_accuracy: 0.7615 - val_loss: 0.7258
# Epoch 3/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7946 - loss: 0.6086 - val_accuracy: 0.8687 - val_loss: 0.4084
# Epoch 4/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8880 - loss: 0.3473 - val_accuracy: 0.9177 - val_loss: 0.2535
# Epoch 5/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9292 - loss: 0.2282 - val_accuracy: 0.9380 - val_loss: 0.1964
# Epoch 6/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9455 - loss: 0.1800 - val_accuracy: 0.9453 - val_loss: 0.1705
# Epoch 7/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9529 - loss: 0.1518 - val_accuracy: 0.9520 - val_loss: 0.1590
# Epoch 8/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9563 - loss: 0.1444 - val_accuracy: 0.9530 - val_loss: 0.1514
# Epoch 9/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9608 - loss: 0.1262 - val_accuracy: 0.9600 - val_loss: 0.1288
# Epoch 10/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9661 - loss: 0.1156 - val_accuracy: 0.9607 - val_loss: 0.1322
# Epoch 11/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9650 - loss: 0.1113 - val_accuracy: 0.9652 - val_loss: 0.1144
# Epoch 12/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9704 - loss: 0.0973 - val_accuracy: 0.9682 - val_loss: 0.1110
# Epoch 13/200
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9717 - loss: 0.0977 - val_accuracy: 0.9668 - val_loss: 0.1074

# %% [markdown]
# ### Evaluation of the Model
#
# First we take a look at the evolution of the loss and the accuracy over the epochs

# %%
def plot_history(history, key):
    plt.figure()
    plt.plot(history.history[key], label='training')
    plt.plot(history.history[f'val_{key}'], label='validation')
    plt.title(f'model {key}')
    plt.ylabel(key)
    plt.xlabel('epoch')
    plt.legend()
    plt.grid()


plot_history(history, 'loss')
plot_history(history, 'accuracy')

# %% [markdown]
# The performance of the trained classifier on the validation examples is summarized in the classification report including various performance metrics

# %%
Y_pred = model.predict(X_test)
print(classification_report(np.argmax(Y_test, axis=1), np.argmax(Y_pred, axis=1)))
# Out:
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97       602
#            1       0.97      0.97      0.97       590
#            2       0.96      0.96      0.96       593
#            3       0.93      0.98      0.95       607
#            4       0.98      0.99      0.99       574
#            5       0.97      0.97      0.97       609
#            6       0.99      0.94      0.97       625
#            7       0.96      0.96      0.96       613
#            8       0.99      0.96      0.97       629
#            9       0.94      0.97      0.96       558
#
#     accuracy                           0.97      6000
#    macro avg       0.97      0.97      0.97      6000
# weighted avg       0.97      0.97      0.97      6000

# %% [markdown]
# **Copyright**
#
# This notebook is provided as [Open Educational Resource](https://de.wikipedia.org/wiki/Open_Educational_Resources).
# The text is licensed under [Creative Commons Attribution 4.0](https://creativecommons.org/licenses/by/4.0/)
# , the code of the IPython examples under the [MIT license](https://opensource.org/licenses/MIT). Please attribute the work as follows: Sascha Spors, Data driven audio signal processing - Lecture supplementals.
